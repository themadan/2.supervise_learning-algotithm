# %% [markdown]
# # Ridge Regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

#Importing dataset
gp=pd.read_csv('gm_2008_region.csv')

#Selecting input and target
x=gp[['child_mortality','fertility','HIV','BMI_male','BMI_female']]
y=gp[['life']]

#Initiating Linear Regression and fitting the model
reg = Ridge(alpha=.4,normalize=True) #try different alpha values
model=reg.fit(x,y)

coef=model.coef_
print(coef)

#Predicitng new target over input
ynew=reg.predict(x)


plt.plot(range(len(x.columns)), coef.T)
plt.xticks(range(len(x.columns)), x, rotation=60)
plt.margins(0.02)
plt.show()

#Print the model and score
print(reg.intercept_,"+",reg.coef_,"X")
print("R^2error:",reg.score(x,y))
print("RMSE error:",np.sqrt(mean_squared_error(y,ynew)))
# Out:
# [[-0.05575342 -1.02675002 -0.47495512  0.73039823 -0.33517292]]
# [100.59493612] + [[-0.05575342 -1.02675002 -0.47495512  0.73039823 -0.33517292]] X
# R^2error 0.8526861499877707
# RMSE error 3.488614794006455

# %% [markdown]
# # Lasso Regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

#Importing dataset
gp=pd.read_csv('gm_2008_region.csv')

#Selecting input and target
x=gp[['child_mortality','fertility','HIV','BMI_male','BMI_female']]
y=gp[['life']]

#Initiating Linear Regression and fitting the model
reg = Lasso(alpha=.4, normalize=True)
model=reg.fit(x,y)

coef=model.coef_
print(coef)

#Predicitng new target over input
ynew=reg.predict(x)

plt.plot(range(len(x.columns)), coef)
plt.xticks(range(len(x.columns)), x, rotation=60)
plt.margins(0.02)
plt.show()

#Print the model and score
print(reg.intercept_,"+",reg.coef_,"X")
print("R^2error:",reg.score(x,y))
print("RMSE error:",np.sqrt(mean_squared_error(y,ynew)))
# Out:
# [-0.07087587 -0.         -0.          0.         -0.        ]
# [72.79917526] + [-0.07087587 -0.         -0.          0.         -0.        ] X
# R^2error 0.4948632173434634
# RMSE error 6.460047705197566
